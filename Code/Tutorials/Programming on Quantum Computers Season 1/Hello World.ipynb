# %%
from qiskit import *
from qiskit_aer import *

# %%
qr = QuantumRegister(2)

# %%
cr = ClassicalRegister(2)

# %%
circuit = QuantumCircuit(qr, cr)

# %%
# %matplotlib inline

# %%
circuit.draw("mpl")

# %%
circuit.h(qr[0])

# %%
circuit.draw("mpl")

# %%
circuit.cx(qr[0], qr[1])

# %%
circuit.draw("mpl")

# %%
circuit.measure(qr, cr)

# %%
circuit.draw("mpl")

# %%
from qiskit.visualization import plot_histogram
from qiskit_ibm_provider import IBMProvider

# %%
IBMProvider.save_account(token="b658ff316fc6a6c564f53d0ec6cd35fba20054772aa56911176ccecc8bcc53e2d105e1cf7db14e37bced4c34ce539d36cc0ddf4ee6370870b83fd72dd7960bd5")
provider = IBMProvider()
simulator = Aer.get_backend("qasm_simulator")
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 IBMProvider.save_account(token="b658ff316fc6a6c564f53d0ec6cd35fba20054772aa56911176ccecc8bcc53e2d105e1cf7db14e37bced4c34ce539d36cc0ddf4ee6370870b83fd72dd7960bd5")
#       2 provider = IBMProvider()
#       3 simulator = Aer.get_backend("qasm_simulator")
#
# File c:\Users\Guan-Xuan Chen\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_ibm_provider\ibm_provider.py:485, in IBMProvider.save_account(token, url, instance, name, proxies, verify, overwrite)
#     458 @staticmethod
#     459 def save_account(
#     460     token: Optional[str] = None,
#    (...)
#     466     overwrite: Optional[bool] = False,
#     467 ) -> None:
#     468     """Save the account to disk for future use.
#     469
#     470     Args:
#    (...)
# ...

# %%
result = simulator.run(circuit, simulator=simulator).result()
plot_histogram(result.get_counts(circuit))

# %%
IBMQ.load_account()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 IBMQ.load_account()
#
# NameError: name 'IBMQ' is not defined
